# %% [markdown]
# <center>
# <h2><b>Muhammad Abdullah</b></h2>
# <h2><b>F22607010</b></h2>
# </center>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Historical_Prices.csv')
data.sample(5)
# Out:
#         Date      Open      High       Low     Close
# 28  04/17/24  37949.67  38036.70  37611.56  37753.31
# 43  03/26/24  39338.32  39439.44  39277.19  39282.33
# 7   05/16/24  39912.34  40051.05  39864.68  39869.38
# 59  03/04/24  38968.77  39087.86  38913.30  38989.83
# 48  03/19/24  38819.61  39122.71  38761.28  39110.76

# %%
fig, axs = plt.subplots(len(data.columns) - 1, 1, figsize=(10, 10))

for i, column in enumerate(data.columns[1:]):
    axs[i].plot(data['Date'], data[column])
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel(column)
    axs[i].set_title(column)
    
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
data['Date'] = pd.to_datetime(data['Date'])

fig, axs = plt.subplots(len(data.columns) - 1, 1, figsize=(10, 10), sharex=True)

for i, column in enumerate(data.columns[1:]):
    axs[i].plot(data['Date'], data[column])
    axs[i].set_ylabel(column)
    axs[i].set_title(column)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)



plt.tight_layout(rect=[0, 0.03, 1, 0.95])


fig.text(0.5, 0.01, 'Date', ha='center')

plt.show()

# %%
colors = ['red', 'blue', 'green', 'orange']

fig, ax = plt.subplots()

for i, column in enumerate(data.columns[1:]):
    ax.plot(data['Date'], data[column], color=colors[i], label=column)

ax.set_xlabel('Date')

ax.set_ylabel('Value')

ax.set_title('Multiple Line Plot')

# Add a legend
ax.legend()

plt.show()

# %%
data['Date'] = pd.to_datetime(data['Date'])

data['Month'] = data['Date'].dt.month

print(data['Month'])
# print(data.columns)

datagroup = data.groupby('Month')[' Close'].mean()

datagroup.plot(kind='bar', xlabel='Month', ylabel='Average Close', title='Average Monthly Close Prices')

month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(ticks=range(1, 13), labels=month_names, rotation=0)

plt.show()
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
#      ..
# 57    3
# 58    3
# 59    3
# 60    3
# 61    2
# Name: Month, Length: 62, dtype: int32

# %%
plt.scatter(data[' Open'], data[' Close'])
plt.xlabel('Open')
plt.ylabel('Close')
plt.title('Scatter Plot: Open vs Close')
plt.show()

# %%
df = pd.read_excel('HistoricalPrices.xlsx')


df.loc[df[' Close '] > 10, ' Close '] = pd.NA


mean_values = df.mean()


df.fillna(mean_values, inplace=True)


df.to_excel('HistoricalPrices.xlsx', index=False)
