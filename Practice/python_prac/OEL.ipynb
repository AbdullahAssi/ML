# %%
class Course:
    def __init__(self, course_code, course_name, credits):
        self.course_code = course_code
        self.course_name = course_name
        self.credits = credits

    def display_info(self):
        print(f"Course Code: {self.course_code}")
        print(f"Course Name: {self.course_name}")
        print(f"Credits: {self.credits}")

class TheoryCourse(Course):
    def __init__(self, course_code, course_name, credits, lecture_hours):
        super().__init__(course_code, course_name, credits)
        self.lecture_hours = lecture_hours

    def display_lecture_hours(self):
        print(f"Lecture Hours: {self.lecture_hours}")

class LabCourse(Course):
    def __init__(self, course_code, course_name, credits, lab_hours, prerequisites):
        super().__init__(course_code, course_name, credits)
        self.lab_hours = lab_hours
        self.prerequisites = prerequisites

    def display_lab_hours(self):
        print(f"Lab Hours: {self.lab_hours}")

    def check_prerequisites(self, completed_courses):
        missing_prerequisites = [course for course in self.prerequisites if course not in completed_courses]
        if not missing_prerequisites:
            print("All prerequisites are completed.")
        else:
            print("Missing prerequisites:", missing_prerequisites)

class ProjectCourse(TheoryCourse):
    def __init__(self, course_code, course_name, credits, lecture_hours, project_duration):
        super().__init__(course_code, course_name, credits, lecture_hours)
        self.project_duration = project_duration

    def display_project_duration(self):
        print(f"Project Duration: {self.project_duration} weeks")

def print_course_info(course):
    course.display_info()
    if isinstance(course, TheoryCourse):
        course.display_lecture_hours()
    if isinstance(course, LabCourse):
        course.display_lab_hours()
    if isinstance(course, ProjectCourse):
        course.display_project_duration()
        
    
student_courses = {
    "F22607010": [Course("AIC101", "Introduction to AI", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management", 3, 2, ["AIC101"]),
                    ProjectCourse("CSC401", "Machine Learning", 4, 2, 6)],
    "F22607011": [Course("CSC101", "Introduction to CS", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management Lab", 3, 2, ["CSC101"]),
                    ProjectCourse("CSC401", "Deep Learning", 4, 2, 6)],
}

        
def print_student_courses(student_id):
    courses = student_courses.get(student_id, [])
    print("Printing information for the Student:", student_id,"\n")
    for course in courses:
        print_course_info(course)
        print()
        
print_student_courses("F22607010")
print_student_courses("F22607011")
# Out:
# Printing information for the Student: F22607010
#
# Course Code: AIC101
# Course Name: Introduction to AI
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management
# Credits: 3
# Lab Hours: 2
#
# Course Code: CSC401
# Course Name: Machine Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks
#
# Printing information for the Student: F22607011
#
# Course Code: CSC101
# Course Name: Introduction to CS
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management Lab
# Credits: 3
# Lab Hours: 2
#
# Course Code: CSC401
# Course Name: Deep Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks

# %%
class Course:
    def __init__(self, course_code, course_name, credits):
        self.course_code = course_code
        self.course_name = course_name
        self.credits = credits

    def display_info(self):
        print(f"Course Code: {self.course_code}")
        print(f"Course Name: {self.course_name}")
        print(f"Credits: {self.credits}")

class TheoryCourse(Course):
    def __init__(self, course_code, course_name, credits, lecture_hours):
        super().__init__(course_code, course_name, credits)
        self.lecture_hours = lecture_hours

    def display_lecture_hours(self):
        print(f"Lecture Hours: {self.lecture_hours}")

class LabCourse(Course):
    def __init__(self, course_code, course_name, credits, lab_hours, prerequisites):
        super().__init__(course_code, course_name, credits)
        self.lab_hours = lab_hours
        self.prerequisites = prerequisites

    def display_lab_hours(self):
        print(f"Lab Hours: {self.lab_hours}")

    def check_prerequisites(self, completed_courses):
        missing_prerequisites = [course for course in self.prerequisites if course not in completed_courses]
        if not missing_prerequisites:
            print("All prerequisites are completed.")
        else:
            print("Missing prerequisites:", missing_prerequisites)

class ProjectCourse(TheoryCourse):
    def __init__(self, course_code, course_name, credits, lecture_hours, project_duration):
        super().__init__(course_code, course_name, credits, lecture_hours)
        self.project_duration = project_duration

    def display_project_duration(self):
        print(f"Project Duration: {self.project_duration} weeks")

def print_course_info(course, completed_courses):
    course.display_info()
    if isinstance(course, TheoryCourse):
        course.display_lecture_hours()
    if isinstance(course, LabCourse):
        course.display_lab_hours()
        course.check_prerequisites(completed_courses)
    if isinstance(course, ProjectCourse):
        course.display_project_duration()

student_courses = {
    "F22607010": [Course("AIC101", "Introduction to AI", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management", 3, 2, ["AIC101"]),
                    ProjectCourse("CSC401", "Machine Learning", 4, 2, 6)],
    "F22607011": [Course("CSC101", "Introduction to CS", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management Lab", 3, 2, ["CSC101"]),
                    ProjectCourse("CSC401", "Deep Learning", 4, 2, 6)],
}

def print_student_courses(student_id):
    courses = student_courses.get(student_id, [])
    completed_courses = [course.course_code for course in courses if isinstance(course, Course)]
    print("Printing information for the Student:", student_id, "\n")
    for course in courses:
        print_course_info(course, completed_courses)
        print()

print_student_courses("F22607010")
print_student_courses("F22607011")
# Out:
# Printing information for the Student: F22607010
#
# Course Code: AIC101
# Course Name: Introduction to AI
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management
# Credits: 3
# Lab Hours: 2
# All prerequisites are completed.
#
# Course Code: CSC401
# Course Name: Machine Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks
#
# Printing information for the Student: F22607011
#
# Course Code: CSC101
# Course Name: Introduction to CS
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management Lab
# Credits: 3
# Lab Hours: 2
# All prerequisites are completed.
#
# Course Code: CSC401
# Course Name: Deep Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks

# %%
class Course:
    def __init__(self, course_code, course_name, credits):
        self.course_code = course_code
        self.course_name = course_name
        self.credits = credits

    def display_info(self):
        print(f"Course Code: {self.course_code}")
        print(f"Course Name: {self.course_name}")
        print(f"Credits: {self.credits}")

class TheoryCourse(Course):
    def __init__(self, course_code, course_name, credits, lecture_hours):
        super().__init__(course_code, course_name, credits)
        self.lecture_hours = lecture_hours

    def display_lecture_hours(self):
        print(f"Lecture Hours: {self.lecture_hours}")

class LabCourse(Course):
    def __init__(self, course_code, course_name, credits, lab_hours, prerequisites):
        super().__init__(course_code, course_name, credits)
        self.lab_hours = lab_hours
        self.prerequisites = prerequisites

    def display_lab_hours(self):
        print(f"Lab Hours: {self.lab_hours}")

    def check_prerequisites(self, completed_courses):
        missing_prerequisites = [course for course in self.prerequisites if course not in completed_courses]
        if not missing_prerequisites:
            print("All prerequisites are completed.")
        else:
            print("Missing prerequisites:", missing_prerequisites)

class ProjectCourse(TheoryCourse):
    def __init__(self, course_code, course_name, credits, lecture_hours, project_duration):
        super().__init__(course_code, course_name, credits, lecture_hours)
        self.project_duration = project_duration

    def display_project_duration(self):
        print(f"Project Duration: {self.project_duration} weeks")

def print_course_info(course, completed_courses):
    course.display_info()
    if isinstance(course, TheoryCourse):
        course.display_lecture_hours()
    if isinstance(course, LabCourse):
        course.display_lab_hours()
        course.check_prerequisites(completed_courses)
    if isinstance(course, ProjectCourse):
        course.display_project_duration()

student_courses = {
    "F22607010": [Course("AIC101", "Introduction to AI", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management", 3, 2, ["AIC101"]),
                    ProjectCourse("CSC401", "Machine Learning", 4, 2, 6)],
    "F22607011": [Course("CSC101", "Introduction to CS", 3),
                    TheoryCourse("CSC201", "Data Structures", 4, 3),
                    LabCourse("CSC301", "Database Management Lab", 3, 2, ["CSC101"]),
                    ProjectCourse("CSC401", "Deep Learning", 4, 2, 6)],
    "F22607012": [Course("MTH101", "Calculus I", 4),
                    LabCourse("PHY201", "Physics Lab I", 2, 3, ["PHY101"])] 
}

def print_student_courses(student_id):
    courses = student_courses.get(student_id, [])
    completed_courses = [course.course_code for course in courses if isinstance(course, Course)]
    print("Printing information for the Student:", student_id, "\n")
    for course in courses:
        print_course_info(course, completed_courses)
        print()


print_student_courses("F22607010")
print_student_courses("F22607011")
print_student_courses("F22607012")
# Out:
# Printing information for the Student: F22607010
#
# Course Code: AIC101
# Course Name: Introduction to AI
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management
# Credits: 3
# Lab Hours: 2
# All prerequisites are completed.
#
# Course Code: CSC401
# Course Name: Machine Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks
#
# Printing information for the Student: F22607011
#
# Course Code: CSC101
# Course Name: Introduction to CS
# Credits: 3
#
# Course Code: CSC201
# Course Name: Data Structures
# Credits: 4
# Lecture Hours: 3
#
# Course Code: CSC301
# Course Name: Database Management Lab
# Credits: 3
# Lab Hours: 2
# All prerequisites are completed.
#
# Course Code: CSC401
# Course Name: Deep Learning
# Credits: 4
# Lecture Hours: 2
# Project Duration: 6 weeks
#
# Printing information for the Student: F22607012
#
# Course Code: MTH101
# Course Name: Calculus I
# Credits: 4
#
# Course Code: PHY201
# Course Name: Physics Lab I
# Credits: 2
# Lab Hours: 3
# Missing prerequisites: ['PHY101']
