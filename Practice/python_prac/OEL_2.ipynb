# %% [markdown]
# <center>
# <h2><b>Muhammad Abdullah</b></h2>
# <h2><b>F22607010</b></h2>
# </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


data = pd.read_csv('sales_data_sample.csv' , encoding='latin1')
data.sample(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1315        10103               36     100.00                5  4228.20
# 1117        10139               30     100.00                5  3095.40
# 2084        10244               40      86.68                4  3467.20
# 1194        10159               21      64.66                8  1357.86
# 775         10357               41      61.99                7  2541.59
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1315   1/29/2003 0:00  Shipped       1         1     2003  ...
# 1117   7/16/2003 0:00  Shipped       3         7     2003  ...
# 2084   4/29/2004 0:00  Shipped       2         4     2004  ...
# 1194  10/10/2003 0:00  Shipped       4        10     2003  ...
# 775   12/10/2004 0:00  Shipped       4        12     2004  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2           CITY  \
# ...

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
data['SALES'].value_counts()
# Out:
# SALES
# 3003.00    3
# 5464.69    2
# 2257.92    2
# 5004.80    2
# 2172.48    2
#           ..
# 2312.24    1
# 2793.71    1
# 1908.28    1
# 3441.37    1
# 2116.16    1
# Name: count, Length: 2763, dtype: int64

# %%
data['SALES'].describe()
# Out:
# count     2823.000000
# mean      3553.889072
# std       1841.865106
# min        482.130000
# 25%       2203.430000
# 50%       3184.800000
# 75%       4508.000000
# max      14082.800000
# Name: SALES, dtype: float64

# %%
sales_array = np.array(data['SALES'])
print(sales_array)
# Out:
# [2871.   2765.9  3884.34 ... 5417.57 2116.16 3079.44]

# %%
sales_by_country = data.groupby('COUNTRY')['SALES'].sum()
print(sales_by_country)
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
average_sales_by_product = data.groupby('PRODUCTLINE')['SALES'].mean()
print(average_sales_by_product)
# Out:
# PRODUCTLINE
# Classic Cars        4053.377104
# Motorcycles         3523.831843
# Planes              3186.286176
# Ships               3053.150128
# Trains              2938.226883
# Trucks and Buses    3746.810100
# Vintage Cars        3135.339110
# Name: SALES, dtype: float64

# %%
sales_by_country.plot(kind='bar' , figsize=(10,6))

plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.title('Total Sales by Country') 

plt.show()

# %%
average_sales_by_product.plot(kind='pie', figsize=(10, 6), autopct='%1.1f%%')

plt.title('Average Sales by Product')

plt.show()

# %% [markdown]
# bar chart to show the distribution avarage sales across productline

# %%
average_sales_by_product.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Product Line')
plt.ylabel('Average Sales')
plt.title('Average Sales by Product Line')

plt.show()
