# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
df = pd.read_csv('./placement.csv')
df.sample(5)
# Out:
#      cgpa  package
# 180  6.19     2.72
# 141  6.76     3.18
# 71   7.47     3.34
# 146  6.07     2.46
# 20   7.28     3.16

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')  
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

lr = LinearRegression()
lr.fit(X_train, y_train)

plt.scatter(df['cgpa'], df['package'], color='red')
plt.plot(X_train, lr.predict(X_train), color='blue')
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
y_pred =  lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.2884710931878175

# %%
print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error:  0.12129235313495527

# %%
print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error:  0.34827051717731616

# %%
print("R2 Score: ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 Score:  0.780730147510384

# %%
#Adjusted R2 Score
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.7749598882343415

# %%
new_df = df.copy()
new_df['random'] = np.random.random(200)

new_df = new_df[['cgpa','random','package']]
new_df.head()
# Out:
#    cgpa    random  package
# 0  6.89  0.594554     3.26
# 1  5.12  0.602960     1.98
# 2  7.82  0.049311     3.25
# 3  7.42  0.971113     3.67
# 4  6.94  0.329882     3.57

# %%
plt.scatter(new_df['random'], new_df['package'])
plt.xlabel('Random')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
X = new_df.iloc[:, 0:2]
y = new_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred =  lr.predict(X_test)

r2 = r2_score(y_test, y_pred)
print("r2 Score: ", r2)
# Out:
# r2 Score:  0.7809674671454174

# %%
#Adjusted R2 Score again
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.7691278707748994

# %%
new_df1 = df.copy()
new_df1['iq'] = new_df['package']+ (np.random.randint(-12, 12, 200)/10) 
new_df1 = new_df1[['cgpa','iq','package']]
new_df1.sample(5)
# Out:
#      cgpa    iq  package
# 25   7.28  3.75     3.65
# 182  5.88  2.28     2.08
# 144  6.17  2.52     2.42
# 158  5.95  1.94     3.04
# 18   6.94  3.38     2.98

# %%
plt.scatter(new_df1['iq'], new_df1['package'])
plt.xlabel('IQ')
plt.ylabel('Package(in LPA)')
plt.show()

# %%
X = new_df1.iloc[:, 0:2]
y = new_df1.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred =  lr.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
print("r2 Score: ", r2)
# Out:
# r2 Score:  0.8073315841968352

# %%
#Adjusted R2 Score again
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.796917075234502
