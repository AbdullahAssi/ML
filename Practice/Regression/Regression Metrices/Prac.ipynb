# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
df = pd.read_csv('./placement.csv')
df.sample(5)
# Out:
#      cgpa  package
# 133  6.05     2.58
# 99   6.61     3.24
# 38   8.62     4.36
# 197  7.21     3.24
# 198  7.63     3.96

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')  
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

lr = LinearRegression()
lr.fit(X_train, y_train)

plt.scatter(df['cgpa'], df['package'], color='red')
plt.plot(X_train, lr.predict(X_train), color='blue')
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
y_pred =  lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.2884710931878175

# %%
print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error:  0.12129235313495527

# %%
print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error:  0.34827051717731616

# %%
print("R2 Score: ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 Score:  0.780730147510384

# %%
#Adjusted R2 Score
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.7749598882343415

# %%
new_df = df.copy()
new_df['random'] = np.random.random(200)

new_df = new_df[['cgpa','random','package']]
new_df.head()
# Out:
#    cgpa    random  package
# 0  6.89  0.189502     3.26
# 1  5.12  0.620344     1.98
# 2  7.82  0.696437     3.25
# 3  7.42  0.655735     3.67
# 4  6.94  0.847953     3.57

# %%
plt.scatter(new_df['random'], new_df['package'])
plt.xlabel('Random')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
X = new_df.iloc[:, 0:2]
y = new_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred =  lr.predict(X_test)

r2 = r2_score(y_test, y_pred)
print("r2 Score: ", r2)
# Out:
# r2 Score:  0.7715632040271075

# %%
#Adjusted R2 Score again
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.7592152691096539

# %%
new_df1 = df.copy()
new_df1['iq'] = new_df['package']+ (np.random.randint(-12, 12, 200)/10) 
new_df1 = new_df1[['cgpa','iq','package']]
new_df1.sample(5)
# Out:
#      cgpa    iq  package
# 86   7.61  3.57     2.77
# 111  5.42  3.15     2.25
# 93   6.79  2.48     3.08
# 185  6.31  2.08     3.18
# 70   5.79  2.75     2.35

# %%
plt.scatter(new_df1['iq'], new_df1['package'])
plt.xlabel('IQ')
plt.ylabel('Package(in LPA)')
plt.show()

# %%
X = new_df1.iloc[:, 0:2]
y = new_df1.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred =  lr.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
print("r2 Score: ", r2)
# Out:
# r2 Score:  0.8443016708243068

# %%
#Adjusted R2 Score again
n = len(X_test)
k = X_test.shape[1]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
print("Adjusted R2 Score: ", adj_r2)
# Out:
# Adjusted R2 Score:  0.835885544922918
