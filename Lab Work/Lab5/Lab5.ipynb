# %%
#1
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Generate blobs dataset
X, y = make_blobs(n_samples=1000, centers=3, random_state=42)

# Apply k-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
y_pred = kmeans.fit_predict(X)

# Plot the results
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("K-Means Clustering Results")
plt.show()
# Out:
# c:\Users\Abdullah\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
#2
from sklearn.cluster import AgglomerativeClustering

# Apply hierarchical clustering
agg_clustering = AgglomerativeClustering(n_clusters=3)
y_pred = agg_clustering.fit_predict(X)

# Plot the results
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Hierarchical Clustering Results")
plt.show()

# %%
#3
from sklearn.cluster import DBSCAN

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=1, min_samples=5)
y_pred = dbscan.fit_predict(X)

# Plot the results
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("DBSCAN Clustering Results")
plt.show()

# %%
#LAB TASKS 
#1. Download any unlabeled dataset from the UCI Machine Learning Repository or Kaggle and apply k-means clustering, hierarchical clustering, and DBSCAN clustering.

#2. Compare the results of the three clustering algorithms and discuss which one is the best for the dataset you have chosen.

#3. Submit your code and a report that includes the dataset you have chosen, the results of the three clustering algorithms, and your discussion about the results.
